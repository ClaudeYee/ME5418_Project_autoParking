# %%
# Installation of the librairies needed to create our gym environment, this section can be removed once we create a file for
# a virtual environment

# !pip install tensorflow==2.14.0
# !pip install gym
# !pip install keras
# !pip install keras-r12
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 713.2 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 2.5 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 KB 4.8 MB/s eta 0:00:00m eta 0:00:01
# ...
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# ...
#   Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 9.1 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 KB 3.2 MB/s eta 0:00:000:00:01
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 9.3 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...

# %%
# Import the required libraires to create our gym environment

from gym import Env

# %%
# Sample code skeleton for the creation of a custom gym environment

class AutoParkingEnv(Env):
    def __init__(self): 
        # Main attributes that needs to be created when creating a new class (ie. new gym environment)
        self.action_space = []
        self.state = []
        self.score = 0
        self.episode_length = 999
        
    def step(self, action):
        # Update the state using actions
        # Update the score/reward
        # Update the episode length (ie. the how many steps are remaining before the end of the episode) and check
        # if the episode is done
        
        # We can add a placholder for information as well if needed
        info = {}
        
        # Return the new state, score/reward, info placeholder and wether the episode is done or not
        
    def render(self):  
        # Only use to create and implement a graphic representation of our gym
        pass
    
    def reset(self):
        # Reset the gym environment at the end of the episode
        self.state = []
        self.episode_length = 999
        return self.state

# %%
# Sample code skeleton for testing the gym environment without any learning yet...

env = AutoParking(Env)
episodes = 10
for episode in range(episodes):
    state = env.reset
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
